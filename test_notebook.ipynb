# %%
from cpb_api.water_quality_api import WaterQualityApi

api = WaterQualityApi()

# %%
# station_list = api.get_stations(geo_attr= 'HUC8', geo_id = '5')
# station_list = api.get_stations(geo_attr= 'CBSegmentShed2009', geo_id = 'CB1TF')

# %%
data = api.get_measurements(geog_id = [4, 6, 8], start_date='11-24-2022', program='all')

# %%
data.Depth.max()
# Out:
# 0.3

# %%
data.columns
# Out:
# Index(['HUC8', 'EventId', 'Cruise', 'Program', 'Project', 'Agency', 'Source',
#        'Station', 'SampleDate', 'SampleTime', 'TotalDepth', 'UpperPycnocline',
#        'LowerPycnocline', 'Depth', 'Layer', 'SampleType',
#        'SampleReplicateType', 'Parameter', 'Qualifier', 'MeasureValue', 'Unit',
#        'Method', 'Lab', 'Problem', 'PrecisionPC', 'BiasPC', 'Details',
#        'Latitude', 'Longitude', 'TierLevel'],
#       dtype='object')

# %%
data.sort_values('SampleDate')
# Out:
#          HUC8  EventId  Cruise Program   Project Agency   Source  \
# 200  02050107   631155  PART22   NTWQM  PARTNTID    CMC     CCST
# 182  02050107   675201  NTN023   NTWQM       NTN  PADEP     SRBC
# 157  02050107   675172  NTN023   NTWQM       NTN  PADEP     SRBC
# 183  02050107   675202  NTN023   NTWQM       NTN  PADEP     SRBC
# 158  02050107   675173  NTN023   NTWQM       NTN  PADEP     SRBC
# ..        ...      ...     ...     ...       ...    ...      ...
# 123  02050107   666053  PART23   NTWQM  PARTNTID    CMC  LCSTA.1
# 145  02050107   666619  PART23   NTWQM  PARTNTID    CMC  LCSTA.1
# 136  02050107   666560  PART23   NTWQM  PARTNTID    CMC     CCST
# 137  02050107   666560  PART23   NTWQM  PARTNTID    CMC     CCST
# 144  02050107   666619  PART23   NTWQM  PARTNTID    CMC  LCSTA.1
#
#                 Station           SampleDate SampleTime  ...   Unit Method  \
# 200     CCST.FISCRE0.49  2022-11-27T00:00:00   15:30:00  ...  DEG C   F01
# ...
